# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
img0 = cv2.imread('c:/Users/APrap/Documents/CREATE/Pick-and-Place/Pictures/Size/Capture.png')
rgb_img0 = cv2.cvtColor(img0, cv2.COLOR_BGR2RGB)
img1 = cv2.imread('c:/Users/APrap/Documents/CREATE/Pick-and-Place/Pictures/Size/Capture1.png')
rgb_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img0)

# %%
dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_50)
parameters =  cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(dictionary, parameters)

# %%
def draw(markerCorners, img):
        
    int_corners = np.int32(markerCorners)

    font = cv2.FONT_HERSHEY_SIMPLEX
    fontScale = 2
    color = (255,0, 0)
    thickness = 4

    out = cv2.polylines(img,  [int_corners], True, (0, 255, 0), 4)
    for i in range(len(int_corners)):
        out = cv2.putText(out, str(i+1), int_corners[i], font, 
                    fontScale, color, thickness, cv2.LINE_AA)
    
    return out

# %%
img = img1.copy()
markerCorners, markerIds, rejectedCandidates = detector.detectMarkers(img)
# print(len(markerCorners[0][0]))
markerCorners = np.array(markerCorners[0][0])

perimeter = cv2.arcLength(markerCorners, True)
pixel_cm_ratio = perimeter / 400
# print(perimeter)

img = draw(markerCorners, img)
center = (img.shape[1]//2, img.shape[0]//2)
print('center ', center)
print('corners ', markerCorners)

print(markerCorners[0][0]-center[0], markerCorners[0][1]-center[1])
   
    
plt.imshow(img)
# Out:
# center  (1218, 601)
# corners  [[1040.  343.]
#  [1370.  343.]
#  [1370.  673.]
#  [1040.  673.]]
# -178.0 -258.0

# %%
a = np.array([[0,1],
              [2,3]])
print(a[0][1])
# Out:
# 1

# %%
img = cv2.imread('c:/Users/APrap/Documents/CREATE/Pick-and-Place/Pictures/detection/image1.png')
img = cv2.circle(img, (585, 468), 3, (0, 0, 255), -1)
img = cv2.circle(img, (605, 368), 3, (0, 0, 255), -1)
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
listA = []

listA.append([1,2])

# %%
listA[0][0]
# Out:
# 1
