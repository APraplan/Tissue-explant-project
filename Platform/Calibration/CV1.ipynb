# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import cv2
import math

import sys
sys.path.append('c:/Users/APrap/Documents/CREATE/Pick-and-Place')

# from skimage import measure, color
plt.rcParams['image.cmap'] = 'gray'

show_all = True

# %%
image = cv2.imread('Pictures/image5.png')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 2
#       1 image = cv2.imread('Pictures/image5.png')
# ----> 2 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       3 plt.imshow(gray_image)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
image_blur = cv2.GaussianBlur(gray_image, (5,5), 0)
if show_all:
    plt.imshow(image_blur)

# %%
mask = np.zeros(image.shape[0:2], dtype='uint8')

for x in range(mask.shape[0]):
    for y in range(mask.shape[1]):
        if math.sqrt((x-mask.shape[0]/2)**2 + (y-mask.shape[1]/2)**2) < 170:
            mask[x, y] = 1
            
if show_all:
    plt.imshow(mask)

# %%
# laplacien = np.uint8(np.absolute(cv2.Laplacian(image_blur, cv2.CV_64F)))
t_lower = 0
t_upper = 60
laplacien = cv2.Canny(image_blur, t_lower, t_upper, L2gradient = True )
if show_all:
    plt.imshow(laplacien)

# %%
_, binary = cv2.threshold(laplacien, 5, 255, cv2.THRESH_BINARY)
binary = cv2.bitwise_and(binary, binary, mask=mask)
if show_all:
    plt.imshow(binary)

# %%
kernel = np.ones((5, 5), np.uint8)
# dilated = cv2.dilate(binary, kernel, iterations=2)
# erroded = cv2.erode(dilated, kernel, iterations=2)
erroded = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
if show_all:
    plt.imshow(erroded)

# %%
samples = []
out = image.copy()
num = 0
size_min = 15
size_max = 40

font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 0.5
color = (0, 255, 0)
thickness = 1

elements = cv2.findContours(erroded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[-2]
for i in range(len(elements)):
    area = cv2.contourArea(elements[i])
    if area > size_min and area < size_max:
        num += 1
        ((x, y), radius) = cv2.minEnclosingCircle(elements[i])
        size, _ = cv2.getTextSize(str(num), font, fontScale, thickness)
        out = cv2.putText(out, str(num), (int(x-size[0]/2),int(y-5)), font, 
                   fontScale, color, thickness, cv2.LINE_AA)
        
        
plt.imshow(out)

# %% [markdown]
# # Results
# Results correct but some false positives due to the light, overal detection about 90% easy to discriminate by size
